# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Create dataframe from a array

# %% [markdown]
# ##  Option 1

# %%
#create array
data=np.array([[1,4],[2,5],[3,6]])

# %%
#create dataframe
df = pd.DataFrame(data,index=['row1','row2','row3'],columns=['col1','col2'])

# %%
print(df)
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# ## option 2

# %%
#create array with list shape
data=[[1,4],[2,5],[3,6]]

# %%
#create dataframe
df=pd.DataFrame(data,index=['row1','row2','row3'],columns=['col1','col2'])

# %%
print(df)
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# # Create dataframe form directory

# %%
states=["Dinajpur",'rangpur','Rajshahi','Syhlet','Dhaka']
population=[133448634198,767440845823,9687476534589,12343548234,34573452452]

# %%
dict={'States':states,'Population':population}

# %%
df_populations=pd.DataFrame(dict)

# %%
print(df_populations)
# Out:
#      States     Population
# 0  Dinajpur   133448634198
# 1   rangpur   767440845823
# 2  Rajshahi  9687476534589
# 3    Syhlet    12343548234
# 4     Dhaka    34573452452

# %%
# Create dataframe form csv file
data_exam=pd.read_csv('StudentData.csv')

# %%
#show first 5 row in a dataframe
data_exam.head()
# Out:
#   STUDENT DATA  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        SR no        Name  Chemistry    Biology    Physcis       Math
# 1            1   Dipongkar         82         87         95         90
# 2            2      Badhon         92         82         92         95
# 3            3  Proshonjit         90         94         83         89
# 4            4      Durjoy         86         80         98        100
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0      Total        Max        Min    Average
# 1        354         95         82       88.5
# 2        361         95         82      90.25
# 3        356         94         83         89
# 4        364        100         80         91

# %%
data_exam
# Out:
#   STUDENT DATA  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        SR no        Name  Chemistry    Biology    Physcis       Math
# 1            1   Dipongkar         82         87         95         90
# 2            2      Badhon         92         82         92         95
# 3            3  Proshonjit         90         94         83         89
# 4            4      Durjoy         86         80         98        100
# 5            5   Shrabonti         90         82         94        100
# 6            6       Surjo         87         99         85         95
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0      Total        Max        Min    Average
# 1        354         95         82       88.5
# 2        361         95         82      90.25
# 3        356         94         83         89
# 4        364        100         80         91
# 5        366        100         82       91.5
# 6        366         99         85       91.5

# %%
#show last five row in data frame
data_exam.tail()
# Out:
#   STUDENT DATA  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2            2      Badhon         92         82         92         95
# 3            3  Proshonjit         90         94         83         89
# 4            4      Durjoy         86         80         98        100
# 5            5   Shrabonti         90         82         94        100
# 6            6       Surjo         87         99         85         95
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 2        361         95         82      90.25
# 3        356         94         83         89
# 4        364        100         80         91
# 5        366        100         82       91.5
# 6        366         99         85       91.5

# %%
#data_exam.head(n)  show first n row in dataframe Same also tail method
data_exam.head(3)
# Out:
#   STUDENT DATA Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        SR no       Name  Chemistry    Biology    Physcis       Math
# 1            1  Dipongkar         82         87         95         90
# 2            2     Badhon         92         82         92         95
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0      Total        Max        Min    Average
# 1        354         95         82       88.5
# 2        361         95         82      90.25

# %%
#show (row,col)
data_exam.shape
# Out:
# (7, 10)

# %%
df_exam=pd.read_csv('StudentsPerformance.csv')
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
